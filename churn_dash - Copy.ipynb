# %% [markdown]
# ### Import all libraries

# %%
import pandas as pd
import numpy as np
import panel as pn
import hvplot.pandas
pn.extension('tabulator')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
df = pd.read_csv('user_data.csv')

# %% [markdown]
# #### create a column for monthly_income

# %%
df['monthly_income'] = np.random.randint(1, 11, size=len(df)) * 1000

# %% [markdown]
# #### create a column for credit_score
# the dataset does not have a column for <b>credit_score</b>
# let's generate random values for credit_score and insert into our dataset

# %%
credit_scores = np.random.randint(low=300, high=850, size=len(df))
df['credit_score'] = credit_scores

# %% [markdown]
# #### create a column for bank_balance
# Similarly, we add another column for <b>bank_balance</b>
# In this case if there is no leave date we insert random balance value otherwise we insert a 0

# %%
bank_balances = np.random.randint(low=100, high=100001, size=len(df))

#Set bank_balance to 0 where leave_date is None
bank_balances[df['leave_date'].isnull()] = 0
df['bank_balance'] = bank_balances

# %% [markdown]
# #### create a column for city

# %%
cities = ['London', 'Birmingham', 'Leeds', 'Glasgow', 'Sheffield',
          'Bradford', 'Manchester', 'Edinburgh', 'Liverpool', 'Bristol', 'Other']
#top 10 cities by population
#src: https://worldpopulationreview.com/countries/cities/united-kingdom
df['city'] = np.random.choice(cities, size=len(df))

# %% [markdown]
# #### create a column to check if a customer has left or not

# %%
df['is_active_customer'] = (df['leave_date'].isnull()).astype(int)

# %%
df['join_year'] = df['join_date'].str.extract(r'^(\d{4})-').astype(int)

# %%
df
# Out:
#          id first_name last_name                email  gender  age  \
# 0         1    Zquqjsp   Kzinjdx  rexydrr@hotmail.com    Male   25
# 1         2    Juwyddl   Dkdipwi  hkpywgq@outlook.com  Female   20
# 2         3    Yjfjodr   Vbrtbkp    zojkhts@yahoo.com  Female   48
# 3         4    Sukpurx   Kyqvwtk    astmqkh@yahoo.com    Male   21
# 4         5    Zprbudk   Ogsmodp    bcayldc@gmail.com  Female   40
# ...     ...        ...       ...                  ...     ...  ...
# 9995   9996    Huvapwm   Hgwohjd    pbpnooo@gmail.com  Female   49
# 9996   9997    Dsosftv   Mhkpqbk  dhjqpve@outlook.com  Female   37
# 9997   9998    Majrzpn   Qvketpx    yemikfj@gmail.com  Female   21
# 9998   9999    Kvwfdnw   Agxazcj  kumgfjb@outlook.com    Male   51
# 9999  10000    Uwaoezk   Nhxtxzn  etfamvz@hotmail.com    Male   24
#
#       months_as_a_customer   join_date  leave_date  join_year
# 0                       74  2016-08-07  2022-09-25       2016
# 1                       45  2019-07-06         NaN       2019
# 2                       76  2015-03-15  2021-06-11       2015
# 3                       69  2017-07-13         NaN       2017
# 4                       12  2021-11-26  2022-12-19       2021
# ...                    ...         ...         ...        ...
# 9995                    10  2020-12-27  2021-11-11       2020
# 9996                    94  2015-06-20         NaN       2015
# 9997                    18  2018-08-18  2020-03-05       2018
# 9998                    46  2019-05-29         NaN       2019
# 9999                    20  2018-03-22  2019-11-25       2018
#
# [10000 rows x 10 columns]

# %% [markdown]
# # creating the dashboard elements / widgets

# %% [markdown]
# ### 1. A slider to select year

# %% [markdown]
# Get all the joining dates and leaving dates of customers. From those dates, we pick the max and min year values.

# %% [markdown]
# #### get max and min of join_date

# %%
join_dates = df['join_date']

# %%
years_join = join_dates.str[:4]
years_join = years_join.astype(int)
min_year_join = years_join.min()
max_year_join = years_join.max()

# %%
min_year_join = int(min_year_join)
min_year_join
# Out:
# 2015

# %%
max_year_join = int(max_year_join)
max_year_join
# Out:
# 2021

# %% [markdown]
# #### get max and min of leave_date

# %%
leave_dates = df['leave_date']

# %%
years_left = leave_dates.str[:4]
years_left = years_left.dropna().astype(int)
min_year_left = years_left.min()
max_year_left = years_left.max()

# %%
min_year_left = int(min_year_left)
min_year_left
# Out:
# 2015

# %%
max_year_left = int(max_year_left)
max_year_left
# Out:
# 2023

# %% [markdown]
# ### the year sliders

# %% [markdown]
# 1. join date slider

# %%
join_slider = pn.widgets.IntSlider(name='Join Date', start=min_year_join,end=max_year_join,value=min_year_join)
join_slider
# Out:
# IntSlider(end=2021, name='Join Date', start=2015, value=2015)

# %% [markdown]
# 2. leave date slider

# %%
leave_slider = pn.widgets.IntSlider(name='Join Date', start=min_year_left,end=max_year_left,value=min_year_left)
leave_slider
# Out:
# IntSlider(end=2023, name='Join Date', start=2015, value=2015)

# %% [markdown]
# ### create two separte dataframes for city based customer analysis
# active and inactive

# %%
active_cust_df = df[df['is_active_customer'] == 1].groupby('city').agg({'monthly_income': 'mean', 'credit_score': 'mean'}).reset_index()
inactive_cust_df = df[df['is_active_customer'] == 0].groupby('city').agg({'monthly_income': 'mean', 'credit_score': 'mean'}).reset_index()

# %%
#round the values to 2 decimal places
active_cust_df = active_cust_df.round({'monthly_income': 2, 'credit_score': 2})
inactive_cust_df = inactive_cust_df.round({'monthly_income': 2, 'credit_score': 2})

# %%
active_cust_df
# Out:
#           city  monthly_income  credit_score  \
# 0   Birmingham         5449.64        592.24
# 1     Bradford         5607.27        578.11
# 2      Bristol         5752.54        584.21
# 3    Edinburgh         5766.67        574.66
# 4      Glasgow         5844.44        575.35
# 5        Leeds         5569.17        564.15
# 6    Liverpool         5579.62        591.14
# 7       London         5890.98        565.02
# 8   Manchester         5279.35        580.49
# 9        Other         5467.58        573.17
# 10   Sheffield         5335.88        571.62
#
#     active_customers_avg_monthly_income  active_customers_avg_credit_score
# 0                               5449.64                             592.24
# 1                               5607.27                             578.11
# 2                               5752.54                             584.21
# 3                               5766.67                             574.66
# 4                               5844.44                             575.35
# 5                               5569.17                             564.15
# 6                               5579.62                             591.14
# 7                               5890.98                             565.02
# 8                               5279.35                             580.49
# 9                               5467.58                             573.17
# 10                              5335.88                             571.62

# %%
inactive_cust_df
# Out:
#           city  monthly_income  credit_score  \
# 0   Birmingham         5364.60        566.98
# 1     Bradford         5584.64        581.48
# 2      Bristol         5569.18        565.46
# 3    Edinburgh         5484.65        580.67
# 4      Glasgow         5632.81        569.75
# 5        Leeds         5317.11        570.88
# 6    Liverpool         5544.90        580.09
# 7       London         5415.66        571.25
# 8   Manchester         5733.45        574.45
# 9        Other         5503.16        575.81
# 10   Sheffield         5506.62        573.09
#
#     inactive_customers_avg_monthly_income  inactive_customers_avg_credit_score
# 0                                 5364.60                               566.98
# 1                                 5584.64                               581.48
# 2                                 5569.18                               565.46
# 3                                 5484.65                               580.67
# 4                                 5632.81                               569.75
# 5                                 5317.11                               570.88
# 6                                 5544.90                               580.09
# 7                                 5415.66                               571.25
# 8                                 5733.45                               574.45
# 9                                 5503.16                               575.81
# 10                                5506.62                               573.09

# %% [markdown]
# #### rename the columns

# %%
active_cust_df['active_customers_avg_monthly_income'] = active_cust_df['monthly_income']
active_cust_df['active_customers_avg_credit_score'] = active_cust_df['credit_score']

# %%
inactive_cust_df['inactive_customers_avg_monthly_income'] = inactive_cust_df['monthly_income']
inactive_cust_df['inactive_customers_avg_credit_score'] = inactive_cust_df['credit_score']

# %% [markdown]
# #### drop the old columns

# %%
active_cust_df = active_cust_df.drop('monthly_income', axis=1)
active_cust_df = active_cust_df.drop('credit_score', axis=1)
inactive_cust_df = inactive_cust_df.drop('monthly_income', axis=1)
inactive_cust_df = inactive_cust_df.drop('credit_score', axis=1)

# %%
active_cust_df
# Out:
#           city  active_customers_avg_monthly_income  \
# 0   Birmingham                              5449.64
# 1     Bradford                              5607.27
# 2      Bristol                              5752.54
# 3    Edinburgh                              5766.67
# 4      Glasgow                              5844.44
# 5        Leeds                              5569.17
# 6    Liverpool                              5579.62
# 7       London                              5890.98
# 8   Manchester                              5279.35
# 9        Other                              5467.58
# 10   Sheffield                              5335.88
#
#     active_customers_avg_credit_score
# 0                              592.24
# 1                              578.11
# 2                              584.21
# 3                              574.66
# 4                              575.35
# 5                              564.15
# 6                              591.14
# 7                              565.02
# 8                              580.49
# 9                              573.17
# 10                             571.62

# %%
inactive_cust_df
# Out:
#           city  inactive_customers_avg_monthly_income  \
# 0   Birmingham                                5364.60
# 1     Bradford                                5584.64
# 2      Bristol                                5569.18
# 3    Edinburgh                                5484.65
# 4      Glasgow                                5632.81
# 5        Leeds                                5317.11
# 6    Liverpool                                5544.90
# 7       London                                5415.66
# 8   Manchester                                5733.45
# 9        Other                                5503.16
# 10   Sheffield                                5506.62
#
#     inactive_customers_avg_credit_score
# 0                                566.98
# 1                                581.48
# 2                                565.46
# 3                                580.67
# 4                                569.75
# 5                                570.88
# 6                                580.09
# 7                                571.25
# 8                                574.45
# 9                                575.81
# 10                               573.09

# %% [markdown]
# # graphs

# %%
yaxis_credit_score = pn.widgets.RadioButtonGroup(name='y-axis', options=['active','inactive'],button_type='success')

# %% [markdown]
# Connect data pipeline with widets

# %% [markdown]
# ##### Convert df to interactive df. We do this to make it possible to use the our data in for interactive visualizations.

# %%
idf = df.interactive()

# %%
join_date_years = idf.join_date.str[:4]

# %%
type(join_slider)
# Out:
# panel.widgets.slider.IntSlider

# %%
type(join_date_years)
# Out:
# hvplot.interactive.Interactive

# %%
data_pipeline = (
    idf[
        (join_date_years <= join_slider) &
        (idf.city.isin(cities))
    ]
    .groupby(['city',idf.join_date.str[:4]])[yaxis_credit_score].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='join_date')
    .reset_index(drop=True)
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13048\3285271138.py in <module>
#       1 data_pipeline = (
#       2     idf[
# ----> 3         (join_date_years <= join_slider) &
#       4         (idf.city.isin(cities))
#       5     ]
#
# ~\anaconda3\lib\site-packages\hvplot\interactive.py in __le__(self, other)
#     307     def __le__(self, other):
#     308         other = other._transform if isinstance(other, Interactive) else other
# --> 309         return self._apply_operator(operator.le, other)
#     310     def __lt__(self, other):
#     311         other = other._transform if isinstance(other, Interactive) else other
#
# ~\anaconda3\lib\site-packages\hvplot\interactive.py in _apply_operator(self, operator, *args, **kwargs)
#     263         transform = new._transform
#     264         transform = type(transform)(transform, operator, *args)
# --> 265         return new._clone(transform)
#     266
#     267     # Builtin functions
#
# ~\anaconda3\lib\site-packages\hvplot\interactive.py in _clone(self, transform, plot, loc, center, dmap, copy, **kwargs)
#     170         else:
#     171             kwargs = dict(self._inherit_kwargs, **dict(self._kwargs, **kwargs))
# --> 172         return type(self)(self._obj, fn=self._fn, transform=transform, plot=plot, depth=depth,
#     173                          loc=loc, center=center, dmap=dmap, **kwargs)
#     174
#
# ~\anaconda3\lib\site-packages\hvplot\interactive.py in __init__(self, obj, transform, fn, plot, depth, loc, center, dmap, inherit_kwargs, max_rows, method, **kwargs)
#     111         self._kwargs = kwargs
#     112         ds = hv.Dataset(self._obj)
# --> 113         self._current = self._transform.apply(ds, keep_index=True, compute=False)
#     114         self._init = True
#     115
#
# ~\anaconda3\lib\site-packages\holoviews\util\transform.py in apply(self, dataset, flat, expanded, ranges, all_values, keep_index, compute, strict)
#     735             drange = ranges.get(eldim, {})
#     736             drange = drange.get('combined', drange)
# --> 737             data = self._apply_fn(dataset, data, fn, fn_name, args,
#     738                                   kwargs, accessor, drange)
#     739         drop_index = keep_index_for_compute and not keep_index
#
# ~\anaconda3\lib\site-packages\holoviews\util\transform.py in _apply_fn(self, dataset, data, fn, fn_name, args, kwargs, accessor, drange)
#     635                         raise e
#     636         else:
# --> 637             data = fn(*args, **kwargs)
#     638
#     639         return data
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __le__(self, other)
#      50     @unpack_zerodim_and_defer("__le__")
#      51     def __le__(self, other):
# ---> 52         return self._cmp_method(other, operator.le)
#      53
#      54     @unpack_zerodim_and_defer("__gt__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# -> 5623             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5624
#    5625         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     281
#     282     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     284
#     285     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~\anaconda3\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<=' not supported between instances of 'str' and 'int'
